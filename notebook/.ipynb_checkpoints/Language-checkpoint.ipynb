# %%
# %load_ext autoreload
# %autoreload 2

import os,sys,inspect
import re
from bs4 import BeautifulSoup
from spacy import displacy
import pandas as pd

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
data_dir = os.path.join(parentdir, 'data')
job_alpha = os.path.join(parentdir, 'src')

print(job_alpha)
if job_alpha not in sys.path:
    sys.path.append(job_alpha)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# d:\dev\py\job-alpha\src

# %%
details = os.path.join(data_dir, 'sample-details.htm')
with open(details, 'r') as myfile:
    details_data=myfile.read().replace('\n', '')
soup = BeautifulSoup(details_data, 'html.parser')
descr = soup.find('div', attrs={'data-automation': 'jobDescription'})
job_details = descr.get_text()
job_details = re.sub(r'\s+', ' ', job_details).strip().lower()
job_details
# Out:
# 'we are looking for full-time and casual sales consultant the applicants must be: experienced in telecommunications sales,customer service and motivated to meet or exceed ongoing store sales and customer expectations. confident in siebel and mnc systems (will be preferred)! self-motivated,team player and have an ability to learn quickly. confident with excellent communication skills, listening skills and able to build great rapport with customers. able to deliver high level of pre and post sales advocacy (nps) strong in organisational and task management skills with attention to detail. professional at all times with excellent personal presentation and people skills. able to work under pressure and deliver daily results. mature with positive and "can do "attitude and a high level of initiative very reliable, punctual, trustworthy and hardworking with good work ethics able to attend day starts, sales and product training sessions as required. able to work weekends and extra hours as and when required to support the business if you think this accurately describes you than this may be your perfect opportunity to join our ambitious team at telstra south yarra. apply by email to: ryan.vanhemert@southyarratelstrastore.com.au very attractive salary and very generous commission available for the right candidate!'

# %%
import spacy

nlp = spacy.load('en')
doc = nlp(job_details)

#docs = [npl(sen) for sen in job_details.split('.')]

# Find named entities, phrases and concepts  
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
print('-----')
for i, token in enumerate(doc):
    print(token.text, token.pos_, token.dep_, token.is_stop)
# Out:
# daily 715 720 DATE
# day 894 897 DATE
# and extra hours 977 992 TIME
# -----
# we PRON nsubj True
# are VERB aux True
# looking VERB ROOT False
# for ADP prep True
# full ADJ amod True
# - PUNCT punct False
# time NOUN nmod False
# and CCONJ cc True
# casual ADJ amod False
# sales NOUN compound False
# consultant NOUN pobj False
# the DET det True
# applicants NOUN nsubj False
# must VERB aux True
# be VERB conj True
# : PUNCT punct False
# experienced VERB acomp False
# in ADP prep True
# telecommunications NOUN compound False
# sales NOUN pobj False
# , PUNCT punct False
# customer NOUN compound False
# service NOUN conj False
# and CCONJ cc True
# motivated VERB conj False
# to PART aux True
# meet VERB xcomp False
# or CCONJ cc True
# exceed VERB conj False
# ongoing ADJ amod False
# store NOUN compound False
# sales NOUN dobj False
# and CCONJ cc True
# customer NOUN compound False
# expectations NOUN conj False
# . PUNCT punct False
# confident ADJ ROOT False
# in ADP prep True
# siebel NOUN pobj False
# and CCONJ cc True
# mnc NOUN conj False
# systems NOUN conj False
# ( PUNCT punct False
# will VERB aux True
# be VERB auxpass True
# preferred VERB parataxis False
# ) PUNCT punct False
# ! PUNCT punct False
# self NOUN npadvmod False
# - PUNCT punct False
# motivated ADJ amod False
# , PUNCT punct False
# team NOUN compound False
# player NOUN ROOT False
# and CCONJ cc True
# have VERB conj True
# an DET det True
# ability NOUN dobj False
# to PART aux True
# learn VERB acl False
# quickly ADV advmod False
# . PUNCT punct False
# confident ADJ ROOT False
# with ADP prep True
# excellent ADJ amod False
# communication NOUN compound False
# skills NOUN pobj False
# , PUNCT punct False
# listening VERB amod False
# skills NOUN conj False
# and CCONJ cc True
# able ADJ conj False
# to PART aux True
# build VERB xcomp False
# great ADJ amod False
# rapport NOUN dobj False
# with ADP prep True
# customers NOUN pobj False
# . PUNCT punct False
# able ADJ ROOT False
# to PART aux True
# deliver VERB xcomp False
# high ADJ amod False
# level NOUN dobj False
# of ADP prep True
# pre NOUN nmod False
# and CCONJ cc True
# post VERB conj False
# sales NOUN compound False
# advocacy NOUN pobj False
# ( PUNCT punct False
# nps INTJ appos False
# ) PUNCT punct False
# strong ADJ advcl False
# in ADP prep True
# organisational ADJ amod False
# and CCONJ cc True
# task NOUN conj False
# management NOUN compound False
# skills NOUN pobj False
# with ADP prep True
# attention NOUN pobj False
# to ADP prep True
# detail NOUN pobj False
# . PUNCT punct False
# professional ADJ ROOT False
# at ADP prep True
# all DET det True
# times NOUN pobj False
# with ADP prep True
# excellent ADJ amod False
# personal ADJ amod False
# presentation NOUN pobj False
# and CCONJ cc True
# people NOUN nsubj False
# skills NOUN conj False
# . PUNCT punct False
# able ADJ ROOT False
# to PART aux True
# work VERB xcomp False
# under ADP prep True
# pressure NOUN pobj False
# and CCONJ cc True
# deliver VERB conj False
# daily ADJ amod False
# results NOUN dobj False
# . PUNCT punct False
# mature VERB ROOT False
# with ADP prep True
# positive ADJ pobj False
# and CCONJ cc True
# " PUNCT punct False
# can VERB aux True
# do VERB conj True
# " PUNCT punct False
# attitude VERB dobj False
# and CCONJ cc True
# a DET det True
# high ADJ amod False
# level NOUN conj False
# of ADP prep True
# initiative NOUN pobj False
# very ADV advmod True
# reliable ADJ conj False
# , PUNCT punct False
# punctual ADJ conj False
# , PUNCT punct False
# trustworthy ADJ conj False
# and CCONJ cc True
# hardworking VERB conj False
# with ADP prep True
# good ADJ amod False
# work NOUN compound False
# ethics NOUN pobj False
# able ADJ advcl False
# to PART aux True
# attend VERB xcomp False
# day NOUN compound False
# starts NOUN dobj False
# , PUNCT punct False
# sales NOUN conj False
# and CCONJ cc True
# product NOUN compound False
# training NOUN compound False
# sessions NOUN conj False
# as ADP mark True
# required VERB advcl False
# . PUNCT punct False
# able ADJ ROOT False
# to PART aux True
# work VERB xcomp False
# weekends NOUN dobj False
# and CCONJ cc True
# extra ADJ amod False
# hours NOUN conj False
# as ADP prep True
# and CCONJ cc True
# when ADV advmod True
# required VERB conj False
# to PART aux True
# support VERB xcomp False
# the DET det True
# business NOUN dobj False
# if ADP mark True
# you PRON nsubj True
# think VERB advcl False
# this DET nsubj True
# accurately ADV advmod False
# describes VERB ccomp False
# you PRON dobj True
# than ADP prep True
# this DET pobj True
# may VERB aux True
# be VERB ccomp True
# your ADJ poss True
# perfect ADJ amod False
# opportunity NOUN attr False
# to PART aux True
# join VERB acl False
# our ADJ poss True
# ambitious ADJ amod False
# team NOUN dobj False
# at ADP prep True
# telstra ADJ amod False
# south ADJ amod False
# yarra NOUN pobj False
# . PUNCT punct False
# apply VERB ROOT False
# by ADP prep True
# email NOUN pobj False
# to ADP prep True
# : PUNCT punct False
# ryan.vanhemert@southyarratelstrastore.com.au PROPN nummod False
# very ADV advmod True
# attractive ADJ amod False
# salary NOUN pobj False
# and CCONJ cc True
# very ADV advmod True
# generous ADJ amod False
# commission NOUN conj False
# available ADJ amod False
# for ADP prep True
# the DET det True
# right ADJ amod False
# candidate NOUN pobj False
# ! PUNCT punct False

# %%
key_words = []
phrase = ''
is_comb = False
for i, token in enumerate(doc):
    if token.pos_ in ['NOUN', 'ADJ', 'CCONJ']:
        is_comb = True
        phrase += token.text + ' '
        #print(token.text, token.pos_, token.dep_, token.is_stop)
    else:
        if is_comb:
            key_words.append(phrase)
            phrase = ''
        is_comb = False

print(','.join(key_words))
# Out:
# full ,time and casual sales consultant ,applicants ,telecommunications sales ,customer service and ,or ,ongoing store sales and customer expectations ,confident ,siebel and mnc systems ,self ,motivated ,team player and ,ability ,confident ,excellent communication skills ,skills and able ,great rapport ,customers ,able ,high level ,pre and ,sales advocacy ,strong ,organisational and task management skills ,attention ,detail ,professional ,times ,excellent personal presentation and people skills ,able ,pressure and ,daily results ,positive and ,and ,high level ,initiative ,reliable ,punctual ,trustworthy and ,good work ethics able ,day starts ,sales and product training sessions ,able ,weekends and extra hours ,and ,business ,your perfect opportunity ,our ambitious team ,telstra south yarra ,email ,attractive salary and ,generous commission available ,right candidate

# %%
noisy_pos_tags = ['PROP', 'PUNCT', 'ADP']
min_token_length = 2

def isNoise(token):     
    is_noise = False
    if token.pos_ in noisy_pos_tags:
        is_noise = True 
    elif token.is_stop == True:
        is_noise = True
    elif len(token.string) <= min_token_length:
        is_noise = True
    return is_noise

def cleanup(token, lower = True):
    if lower:
       token = token.lower()
    return token.strip()



from collections import Counter
cleaned_list = [cleanup(word.string) for word in doc if not isNoise(word)]
Counter(cleaned_list).most_common(10)
# Out:
# [('sales', 5),
#  ('able', 5),
#  ('skills', 4),
#  ('work', 3),
#  ('customer', 2),
#  ('motivated', 2),
#  ('confident', 2),
#  ('team', 2),
#  ('excellent', 2),
#  ('deliver', 2)]

# %%
# distill into noun chunks
# print(', '.join([chunk.text for chunk in doc.noun_chunks]))
print('-----')

# extract object based noun chunks
objs = [chunk.text for chunk in doc.noun_chunks if chunk.root.dep_ == 'pobj']
print(', '.join(objs))

print('-----')
# conjunctions with a root which is an object
roots = [chunk.root.text for chunk in doc.noun_chunks if chunk.root.dep_ == 'pobj']
conj = [chunk for chunk in doc.noun_chunks if chunk.root.dep_ == 'conj']
conj_add = ['%s %s' % (chunk.root.head.text, chunk.text) for chunk in conj if chunk.root.head.text in roots]
print(', '.join(conj_add))

print('-----')
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text)
# Out:
# -----
# full-time and casual sales consultant, telecommunications sales, siebel, excellent communication skills, customers, pre and post sales advocacy, organisational and task management skills, attention, detail, all times, excellent personal presentation, pressure, initiative, good work ethics, telstra south yarra, email, ryan.vanhemert@southyarratelstrastore.com.au very attractive salary, the right candidate
# -----
# sales customer service, sales customer expectations, siebel mnc, siebel systems, skills listening skills, sales product training sessions, salary very generous commission
# -----
# we we nsubj looking
# full-time and casual sales consultant consultant pobj for
# the applicants applicants nsubj be
# telecommunications sales sales pobj in
# customer service service conj sales
# ongoing store sales sales dobj exceed
# customer expectations expectations conj sales
# siebel siebel pobj in
# mnc mnc conj siebel
# systems systems conj siebel
# self-motivated,team player player ROOT player
# an ability ability dobj have
# excellent communication skills skills pobj with
# listening skills skills conj skills
# great rapport rapport dobj build
# customers customers pobj with
# high level level dobj deliver
# pre and post sales advocacy advocacy pobj of
# organisational and task management skills skills pobj in
# attention attention pobj with
# detail detail pobj to
# all times times pobj at
# excellent personal presentation presentation pobj with
# people people nsubj skills
# pressure pressure pobj under
# daily results results dobj deliver
# a high level level conj attitude
# initiative initiative pobj of
# good work ethics ethics pobj with
# day starts starts dobj attend
# sales sales conj starts
# product training sessions sessions conj sales
# weekends weekends dobj work
# extra hours hours conj weekends
# the business business dobj support
# you you nsubj think
# you you dobj describes
# your perfect opportunity opportunity attr be
# our ambitious team team dobj join
# telstra south yarra yarra pobj at
# email email pobj by
# ryan.vanhemert@southyarratelstrastore.com.au very attractive salary salary pobj to
# very generous commission commission conj salary
# the right candidate candidate pobj for

# %%
for token in doc:
    if token.pos_ is not 'PUNCT':# and not token.is_stop:
        print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
              token.shape_, token.is_alpha, token.is_stop)
# Out:
# au au DET DT ROOT xx True False
# very very ADV RB advmod xxxx True True
# attractive attractive ADJ JJ amod xxxx True False
# salary salary NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# very very ADV RB advmod xxxx True True
# generous generous ADJ JJ amod xxxx True False
# commission commission NOUN NN conj xxxx True False
# available available ADJ JJ amod xxxx True False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# right right ADJ JJ amod xxxx True False
# candidate candidate NOUN NN pobj xxxx True False

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 140})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="28050" height="977.0" style="max-width: none; height: 977.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">looking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">full-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">casual</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">sales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">consultant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">applicants</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">must</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">be:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">experienced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">telecommunications</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2430">sales,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2710">service</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="2990">motivated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2990">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3270">meet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">exceed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3690">ongoing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3690">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3830">store</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3830">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="3970">sales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="4110">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4110">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="887.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentCol

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">we are looking for full-time and casual sales consultant the applicants must be: experienced in telecommunications sales,customer service and motivated to meet or exceed ongoing store sales and customer expectations. confident in siebel and mnc systems (will be preferred)! self-motivated,team player and have an ability to learn quickly. confident with excellent communication skills, listening skills and able to build great rapport with customers. able to deliver high level of pre and post sales advocacy (nps) strong in organisational and task management skills with attention to detail. professional at all times with excellent personal presentation and people skills. able to work under pressure and deliver
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  results. mature with positive and "can do "attitude and a high level of initiative very reliable, punctual, trustworthy and hardworking with good work ethics able to attend
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  starts, sales and product training sessions as required. able to work weekends
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     and extra hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  as and when required to support the business if you think this accurately describes you than this may be your perfect opportunity to join our ambitious team at telstra south yarra. apply by email to: ryan.vanhemert@southyarratelstrastore.com.au very attractive salary and very generous commission available for the right candidate!</div>

# %%
import explacy
explacy.print_parse_info(nlp, 'The salad was surprisingly tasty.')
# Out:
# Dep tree Token        Dep type Lemma        Part of Sp
# ──────── ──────────── ──────── ──────────── ──────────
#    ┌─►   The          det      the          DET
# ┌─►└──   salad        nsubj    salad        NOUN
# └┬┬┬──   was          ROOT     be           VERB
#  ││└─►   surprisingly advmod   surprisingly ADV
#  │└──►   tasty        acomp    tasty        ADJ
#  └───►   .            punct    .            PUNCT

# %%
for sen in job_details.split('.'):
    sen = sen.strip()
    doc = nlp(sen)
    try:
        explacy.print_parse_info(nlp, sen)
    except:
        pass
    displacy.render(doc, style='dep', jupyter=True, options={'distance': 140})
# Out:
# Dep tree                          Token              Dep type Lemma              Part of Sp
# ───────────────────────────────── ────────────────── ──────── ────────────────── ──────────
#                              ┌──► we                 nsubj    -PRON-             PRON
#                              │┌─► are                aux      be                 VERB
# ┌───────────────────┬────────┴┴── looking            ROOT     look               VERB
# │                   └─►┌───────── for                prep     for                ADP
# │                      │     ┌──► full               amod     full               ADJ
# │                      │     │┌─► -                  punct    -                  PUNCT
# │                      │  ┌─►└┼── time               nmod     time               NOUN
# │                      │  │   └─► and                cc       and                CCONJ
# │                      │  │  ┌──► casual             amod     casual             ADJ
# │                      │  │  │┌─► sales              compound sale               NOUN
# │                      └─►└──┴┴── consultant         pobj     consultant         NOUN
# │                             ┌─► the                det      the                DET
# │                          ┌─►└── applicants         nsubj    applicant          NOUN
# │                          │  ┌─► must               aux      must               VERB
# └─►┌───────────────────────┴──┼── be                 conj     be                 VERB
#    │                          └─► :                  punct    :                  PUNCT
#    └─►┌────────────────────────── experienced        acomp    experience         VERB
#       └─►┌─────────────────────── in                 prep     in                 ADP
#          │                    ┌─► telecommunications compound telecommunications NOUN
#          └─►┌─────────────────┼── sales              pobj     sale               NOUN
#             │                 └─► ,                  punct    ,                  PUNCT
#             │                 ┌─► customer           compound customer           NOUN
#             └─►┌──────────────┼── service            conj     service            NOUN
#                │              └─► and                cc       and                CCONJ
#                └─►┌────────────── motivated          conj     motivate           VERB
#                   │           ┌─► to                 aux      to                 PART
#                   └─►┌────────┼── meet               xcomp    meet               VERB
#                      │        └─► or                 cc       or                 CCONJ
#                      └─►┌──────── exceed             conj     exceed             VERB
#                         │    ┌──► ongoing            amod     ongoing            ADJ
#                         │    │┌─► store              compound store              NOUN
#                         └─►┌─┴┼── sales              dobj     sale               NOUN
#                            │  └─► and                cc       and                CCONJ
#                            │  ┌─► customer           compound customer           NOUN
#                            └─►└── expectations       conj     expectation        NOUN
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="4530" height="557.0" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">looking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">full-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">casual</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">sales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">consultant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">applicants</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">must</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">be:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">experienced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">telecommunications</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2430">sales,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2710">service</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2990">motivated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2990">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3270">meet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">exceed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3690">ongoing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3690">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3830">store</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3830">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3970">sales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="4110">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4110">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColo
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="2850" height="417.0" style="max-width: none; height: 417.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">confident</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">siebel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">mnc</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">systems (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">preferred)!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">self-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">motivated,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">team</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">player</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">ability</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2430">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2430">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">learn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2710">quickly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,282.0 C70,212.0 175.0,212.0 175.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M175.0,284.0 L183.0,272.0 167.0,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M210,282.0 C210,212.0 315.0,212.0 315.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M315.0,284.0 L323.0,272.0 307.0,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M350,282.0 C350,212.0 455.0,212.0 455.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M455.0,284.0 L463.0,272.0 447.0,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M350,282.0 C350,142.0 600.0,142.0 600.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M600.0,284.0 L608.0,272.0 592.0,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M350,282.0 C350,72.0 745.0,72.0 745.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,284.0 L753.0,272.0 737.0,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M910,282.0 C910,142.0 1160.0,142.0 1160.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href
# Dep tree               Token         Dep type Lemma         Part of Sp
# ────────────────────── ───────────── ──────── ───────────── ──────────
# ┌───────────────────── confident     ROOT     confident     ADJ
# └─►┌────────────────── with          prep     with          ADP
#    │              ┌──► excellent     amod     excellent     ADJ
#    │              │┌─► communication compound communication NOUN
#    └─►┌───────────┴┼── skills        pobj     skill         NOUN
#       │            └─► ,             punct    ,             PUNCT
#       │            ┌─► listening     amod     listen        VERB
#       └─►┌─────────┼── skills        conj     skill         NOUN
#          │         └─► and           cc       and           CCONJ
#          └─►┌───────── able          conj     able          ADJ
#             │      ┌─► to            aux      to            PART
#             └─►┌┬──┴── build         xcomp    build         VERB
#                ││  ┌─► great         amod     great         ADJ
#                │└─►└── rapport       dobj     rapport       NOUN
#                └──►┌── with          prep     with          ADP
#                    └─► customers     pobj     customer      NOUN
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="2150" height="347.0" style="max-width: none; height: 347.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">confident</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">excellent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">communication</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">skills,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">listening</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">skills</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">able</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">rapport</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">customers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,212.0 C70,142.0 180.0,142.0 180.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180.0,214.0 L188.0,202.0 172.0,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M350,212.0 C350,72.0 605.0,72.0 605.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350,214.0 L342,202.0 358,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M490,212.0 C490,142.0 600.0,142.0 600.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M490,214.0 L482,202.0 498,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M210,212.0 C210,2.0 610.0,2.0 610.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610.0,214.0 L618.0,202.0 602.0,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M770,212.0 C770,142.0 880.0,142.0 880.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,214.0 L762,202.0 778,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M630,212.0 C630,72.0 885.0,72.0 885.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M885.0,214.0 L893.0,202.0 877.0,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M910,212.0 C910,142.0 1020.0,142.0 1020.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1020.0,214.0 L1028.0,202.0 1012.0,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M910,212.0 C910,72.0 1165.0,72.0 1165.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1165.0,214.0 L1173.0,202.0 1157.0,202.0" fill="currentColor"/>
# </g>
#
# <
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="3270" height="557.0" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">able</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">deliver</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">high</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">level</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">pre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">post</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">sales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">advocacy (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">nps)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">strong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">organisational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">task</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2430">management</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">skills</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2710">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">attention</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2990">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2990">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">detail</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M210,422.0 C210,352.0 305.0,352.0 305.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210,424.0 L202,412.0 218,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M70,422.0 C70,282.0 310.0,282.0 310.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310.0,424.0 L318.0,412.0 302.0,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M490,422.0 C490,352.0 585.0,352.0 585.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M490,424.0 L482,412.0 498,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M350,422.0 C350,282.0 590.0,282.0 590.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M590.0,424.0 L598.0,412.0 582.0,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="dis
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1590" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">professional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">times</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">excellent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">personal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">presentation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">skills</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,352.0 C70,282.0 170.0,282.0 170.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170.0,354.0 L178.0,342.0 162.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M350,352.0 C350,282.0 450.0,282.0 450.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350,354.0 L342,342.0 358,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M210,352.0 C210,212.0 455.0,212.0 455.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M455.0,354.0 L463.0,342.0 447.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M70,352.0 C70,72.0 605.0,72.0 605.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M605.0,354.0 L613.0,342.0 597.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M770,352.0 C770,212.0 1015.0,212.0 1015.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M910,352.0 C910,282.0 1010.0,282.0 1010.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910,354.0 L902,342.0 918,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M630,352.0 C630,142.0 1020.0,142.0 1020.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1020.0,354.0 L1028.0,342.0 1012.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M1050,352.0 C1050,282.0 1150.0,282.0 1150.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1150.0,354.0 L1158.0,342.0 1142.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-8" stroke-width="2px" d="M1050,352.0 C1050,212.0 1295.0,212.0 1295.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-8" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295.0,354.0 L1303.0,342.0 1287.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-9" stroke-width="2px" d="M70,352.0 C70,2.0 1450.0,2.0 1450.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-9" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,354.0 L1458.0,342.0 1442.0,342.0" fill="
# Dep tree     Token    Dep type Lemma    Part of Sp
# ──────────── ──────── ──────── ──────── ──────────
# ┌─────────── able     ROOT     able     ADJ
# │        ┌─► to       aux      to       PART
# └─►┌─┬┬──┴── work     xcomp    work     VERB
#    │ │└─►┌── under    prep     under    ADP
#    │ │   └─► pressure pobj     pressure NOUN
#    │ └─────► and      cc       and      CCONJ
#    └─►┌───── deliver  conj     deliver  VERB
#       │  ┌─► daily    amod     daily    ADJ
#       └─►└── results  dobj     result   NOUN
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1310" height="417.0" style="max-width: none; height: 417.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">able</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">work</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">pressure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">deliver</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">daily</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">results</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M210,282.0 C210,212.0 315.0,212.0 315.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
# ...
#     <tspan class="displacy-word" fill="currentColor" x="3410">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="3690">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3690">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="3830">perfect</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3830">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="3970">opportunity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="4110">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4110">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">join</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="677.0">
# Dep tree Token Dep type Lemma Part of Sp
# ──────── ───── ──────── ───── ──────────
# ┌┬┬───── apply ROOT     apply VERB
# ││└─►┌── by    prep     by    ADP
# ││   └─► email pobj     email NOUN
# │└──►┌── to    prep     to    ADP
# │    └─► :     punct    :     PUNCT
# └──────► ryan  conj     ryan  ADJ
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="750" height="347.0" style="max-width: none; height: 347.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">apply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">email</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">to:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="257.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">ryan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,212.0 C70,142.0 180.0,142.0 180.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180.0,214.0 L188.0,202.0 172.0,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M210,212.0 C210,142.0 320.0,142.0 320.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320.0,214.0 L328.0,202.0 312.0,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M70,212.0 C70,72.0 465.0,72.0 465.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M465.0,214.0 L473.0,202.0 457.0,202.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M70,212.0 C70,2.0 610.0,2.0 610.0,212.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610.0,214.0 L618.0,202.0 602.0,202.0" fill="currentColor"/>
# </g>
# </svg>
# Dep tree Token                            Dep type Lemma                            Part of Sp
# ──────── ──────────────────────────────── ──────── ──────────────────────────────── ──────────
#          vanhemert@southyarratelstrastore ROOT     vanhemert@southyarratelstrastore ADJ
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="190" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">vanhemert@southyarratelstrastore</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
# </svg>
# Dep tree Token Dep type Lemma Part of Sp
# ──────── ───── ──────── ───── ──────────
#          com   ROOT     com   NOUN
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="190" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">com</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg>
# Dep tree             Token      Dep type Lemma      Part of Sp
# ──────────────────── ────────── ──────── ────────── ──────────
# ┌┬────────────────── au         ROOT     au         DET
# ││               ┌─► very       advmod   very       ADV
# ││            ┌─►└── attractive amod     attractive ADJ
# │└─►┌─────────┴──┬── salary     pobj     salary     NOUN
# │   │            └─► and        cc       and        CCONJ
# │   │            ┌─► very       advmod   very       ADV
# │   │         ┌─►└── generous   amod     generous   ADJ
# │   └─►┌──────┴───── commission conj     commission NOUN
# │      └─►┌───────── available  amod     available  ADJ
# │         └─►┌────── for        prep     for        ADP
# │            │  ┌──► the        det      the        DET
# │            │  │┌─► right      amod     right      ADJ
# │            └─►└┴── candidate  pobj     candidate  NOUN
# └──────────────────► !          punct    !          PUNCT
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1870" height="417.0" style="max-width: none; height: 417.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">au</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">attractive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">salary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">generous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">commission</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">available</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">right</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">candidate!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M210,282.0 C210,212.0 315.0,212.0 315.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210,284.0 L202,272.0 218,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M350,282.0 C350,212.0 455.0,212.0 455.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350,284.0 L342,272.0 358,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M70,282.0 C70,72.0 465.0,72.0 465.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M465.0,284.0 L473.0,272.0 457.0,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M490,282.0 C490,212.0 595.0,212.0 595.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595.0,284.0 L603.0,272.0 587.0,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M770,282.0 C770,212.0 875.0,212.0 875.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,284.0 L762,272.0 778,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M910,282.0 C910,212.0 1015.0,212.0 1015.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910,284.0 L902,272.0 918,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M490,282.0 C490,2.0 1030.0,2.0 1030.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1030.0,284.0 L1038.0,272.0 1022.0,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M1050,282.0 C1050,212.0 1155.0,212.0 1155.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1155.0,284.0 L1163.0,272.0 1147.0,272.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-8" stroke-width="2px" d="M1190,282.0 C1190,212.0 1295.0,212.0 1295.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-8" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295.0,284.0 L1303.0,272.0 1287.0,272.0" fill="currentColor"/>
# </

# %%
# Out:
# a $4.5 billion project, a new team, accordance, the mine plan
# -----
